# %% [markdown]
# # Spectral Geometry Explorer — Analysis
#
# Use this notebook to run experiments, compare shapes, and generate plots.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from src import geometry, solver, visualize

# %%
domain = geometry.create_domain(shape='circle', resolution=90)
result = solver.solve_eigenmodes(domain, k=8)
visualize.showcase_modes(result, cols=4)

# %%
from pathlib import Path
from IPython.display import display, Image

assets = [
    ("Circle", Path("../data/domains/circle_modes.png")),
    ("L-shape", Path("../data/domains/lshape_modes.png")),
    ("Annulus", Path("../data/domains/annulus_modes.png")),
]

for label, path in assets:
    if path.exists():
        display(Image(filename=str(path), embed=True))
    else:
        print(f"Missing asset: {label} -> {path}")
