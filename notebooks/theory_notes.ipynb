# %% [markdown]
# # Theory Notes
#
# Derivations, references, and checklists for the Laplace eigenvalue problem.

# %% [markdown]
# ## Governing Equation
# $$\Delta v + \lambda v = 0, \quad v|_{\partial \Omega} = 0$$

# %% [markdown]
# ## Weyl's Law
# $$N(\lambda) \sim rac{|\Omega|}{4\pi} \lambda \quad (\lambda 	o \infty)$$
